# %%
from bs4 import BeautifulSoup
import requests

# %%
r = requests.get('https://www.wunderground.com/history/daily/tr/istanbul/LTBA/date/2023-2-4')
soup = BeautifulSoup(r.content, 'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/Organization" lang="en" prefix="og: http://ogp.me/ns#"><head itemscope="" itemtype="http://schema.org/WebSite">
# <meta charset="utf-8"/>
# <title>Istanbul, Türkiye Weather History | Weather Underground</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="//widgets.outbrain.com" rel="dns-prefetch"/>
# <link href="//odb.outbrain.com" rel="dns-prefetch"/>
# <link href="//c.amazon-adsystem.com" rel="dns-prefetch"/>
# <link href="//s.amazon-adsystem.com" rel="dns-prefetch"/>
# <link href="//aax.amazon-adsystem.com" rel="dns-prefetch"/>
# <link href="//partner.googleadservices.com" rel="dns-prefetch"/>
# <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//h.nexac.com" rel="dns-prefetch"/>
# ...

# %%
list_links = list()
base_link = "https://www.wunderground.com/history/daily/tr/istanbul/LTBA/date/"
for years in range(2020,2023):
    for months in range(1,13):
        for days in range (1,29):
            date_link = base_link+str(years)+"-"+str(months)+"-"+str(days)
            list_links.append(date_link)

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.wunderground.com/history/daily/tr/istanbul/LTBA/date/2023-2-2"
html = requests.get(url).content
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/Organization" lang="en" prefix="og: http://ogp.me/ns#"><head itemscope="" itemtype="http://schema.org/WebSite">
# <meta charset="utf-8"/>
# <title>Istanbul, Türkiye Weather History | Weather Underground</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="//widgets.outbrain.com" rel="dns-prefetch"/>
# <link href="//odb.outbrain.com" rel="dns-prefetch"/>
# <link href="//c.amazon-adsystem.com" rel="dns-prefetch"/>
# <link href="//s.amazon-adsystem.com" rel="dns-prefetch"/>
# <link href="//aax.amazon-adsystem.com" rel="dns-prefetch"/>
# <link href="//partner.googleadservices.com" rel="dns-prefetch"/>
# <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//h.nexac.com" rel="dns-prefetch"/>
# ...

# %% [markdown]
# I gave up on using Beautiful Soup, it seems to be going easy by Selenium
